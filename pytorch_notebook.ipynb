# %%
import torch
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
print(f"MPS available: {torch.backends.mps.is_available()}")
print(f"MPS built: {torch.backends.mps.is_built()}")

# Get system info
# !system_profiler SPHardwareDataType | grep "Chip"
# !sysctl -n machdep.cpu.brand_string

# Check memory
# !system_profiler SPHardwareDataType | grep "Memory"
# Out:
# MPS available: True
# MPS built: True
# 2026-06-19 10:29:54.872 system_profiler[8767:477502] hw.cpufamily: 0x6f5129ac
#       Chip: Apple M4
# Apple M4
# 2026-06-19 10:29:55.347 system_profiler[8774:477559] hw.cpufamily: 0x6f5129ac
#       Memory: 16 GB

# %%
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("MPS available! Using Apple GPU")
else:
    device = torch.device("cpu")
    print("MPS not available, using CPU")
# Out:
# MPS available! Using Apple GPU

# %%
print(torch.__version__)
# Out:
# 2.8.0

# %% [markdown]
# # Tensors

# %%
# scalar
scalar= torch.tensor(7, dtype=int32, requires_grad=True)
scalar
# Out:
# tensor(7)
